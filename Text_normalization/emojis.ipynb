# %%
import emoji

# %%
s = 'Hellooooo ✌️'
emoji.replace_emoji(s,"")
# Out:
# 'Hellooooo '

# %%
s = 'Hellooooo ✌️💔❤️❌🤔'
emoji.demojize(s)
# Out:
# 'Hellooooo :victory_hand::broken_heart::red_heart::cross_mark::thinking_face:'
