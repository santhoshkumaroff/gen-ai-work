# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (3.9.2)
# Requirement already satisfied: click in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from nltk) (2026.1.15)
# Requirement already satisfied: tqdm in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from nltk) (4.65.2)
# Requirement already satisfied: colorama in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from click->nltk) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import nltk

# %%
# import nltk

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
res = '''Return a tokenized     copy of text, using NLTK's recommended word tokenizer (currently an improved.
              TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language).
Parameters text : str text to split into words'''

# %%
word_tokens = word_tokenize(res)

# %%
sent_tokens = sent_tokenize(res)

# %%
sent_tokens
# Out:
# ["Return a tokenized     copy of text, using NLTK's recommended word tokenizer (currently an improved.",
#  'TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language).',
#  'Parameters text : str text to split into words']

# %%
res = '''Return a tokenized copy of text, using NLTK's recommended word tokenizer (currently an improved.
              TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language).
Parameters text : str text to split into words'''
res.split()
# Out:
# ['Return',
#  'a',
#  'tokenized',
#  'copy',
#  'of',
#  'text,',
#  'using',
#  "NLTK's",
#  'recommended',
#  'word',
#  'tokenizer',
#  '(currently',
#  'an',
#  'improved.',
#  'TreebankWordTokenizer',
#  'along',
#  'with',
#  '.PunktSentenceTokenizer',
#  'for',
#  'the',
#  'specified',
#  'language).',
#  'Parameters',
#  'text',
#  ':',
#  'str',
#  'text',
#  'to',
#  'split',
#  'into',
#  'words']

# %%
word_tokens
# Out:
# ['Return',
#  'a',
#  'tokenized',
#  'copy',
#  'of',
#  'text',
#  ',',
#  'using',
#  'NLTK',
#  "'s",
#  'recommended',
#  'word',
#  'tokenizer',
#  '(',
#  'currently',
#  'an',
#  'improved',
#  '.',
#  'TreebankWordTokenizer',
#  'along',
#  'with',
#  '.PunktSentenceTokenizer',
#  'for',
#  'the',
#  'specified',
#  'language',
#  ')',
#  '.',
#  'Parameters',
#  'text',
#  ':',
#  'str',
#  'text',
#  'to',
#  'split',
#  'into',
#  'words']

# %%
res.split(".")
# Out:
# ["Return a tokenized copy of text, using NLTK's recommended word tokenizer (currently an improved",
#  '\n              TreebankWordTokenizer along with ',
#  'PunktSentenceTokenizer for the specified language)',
#  '\nParameters text : str text to split into words']

# %%
sent_tokens
# Out:
# ["Return a tokenized copy of text, using NLTK's recommended word tokenizer (currently an improved.",
#  'TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language).',
#  'Parameters text : str text to split into words']

# %%
import re

re.findall(r'\s+',res)
# re.sub(r'\s+','',res)
# Out:
# "Returnatokenizedcopyoftext,usingNLTK'srecommendedwordtokenizer(currentlyanimproved.TreebankWordTokenizeralongwith.PunktSentenceTokenizerforthespecifiedlanguage).Parameterstext:strtexttosplitintowords"

# %%
re.sub(r'\s{2,}','',res)
# Out:
# "Return a tokenizedcopy of text, using NLTK's recommended word tokenizer (currently an improved.TreebankWordTokenizer along with .PunktSentenceTokenizer for the specified language).\nParameters text : str text to split into words"

# %%
re.sub(r'[^a-zA-Z0-9]',' ',res)
# Out:
# 'Return a tokenized     copy of text  using NLTK s recommended word tokenizer  currently an improved                TreebankWordTokenizer along with  PunktSentenceTokenizer for the specified language   Parameters text   str text to split into words'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
