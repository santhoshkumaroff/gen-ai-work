# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
# nltk.download('wordnet')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('averaged_perceptron_tagger_eng')

# %%
tokens = ['houses','running', 'dogs', 'better', 'cats', 'flying', 'geese', 'studies', 'wolves', 'children', 'feet']

# %%
lemmatizer = WordNetLemmatizer()

# %%
for word in tokens:
    print(word,lemmatizer.lemmatize(word,pos='a'))
# Out:
# houses houses
# running running
# dogs dogs
# better good
# cats cats
# flying flying
# geese geese
# studies studies
# wolves wolves
# children children
# feet feet

# %%
''' 
The Part Of Speech tag. Valid options are "n" for nouns,
"v" for verbs, "a" for adjectives, 
"r" for adverbs and "s" for satellite adjectives.
'''
# Out:
# ' \nThe Part Of Speech tag. Valid options are "n" for nouns,\n"v" for verbs, "a" for adjectives, \n"r" for adverbs and "s" for satellite adjectives.\n'

# %%
nltk.pos_tag(tokens)
''' 
N - 'n'
V = 'v'
JJ = 'a' adjectives
RBR = 'r'

'n'
'''
# Out:
# " \nN - 'n'\nV = 'v'\nJJ = 'a' adjectives\nRBR = 'r'\n\n'n'\n"

# %%
def find_postag(tag): #NNS
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('R'):
        return 'r'
    else:
        return 'n'

# %%
pos_tag_words = nltk.pos_tag(tokens)
pos_tag_words
# Out:
# [('houses', 'NNS'),
#  ('running', 'VBG'),
#  ('dogs', 'NNS'),
#  ('better', 'RBR'),
#  ('cats', 'NNS'),
#  ('flying', 'VBG'),
#  ('geese', 'JJ'),
#  ('studies', 'NNS'),
#  ('wolves', 'VBZ'),
#  ('children', 'NNS'),
#  ('feet', 'NNS')]

# %%
for word,tag in pos_tag_words: #('houses', 'NNS')
    tagged_word = lemmatizer.lemmatize(word,find_postag(tag)) 
    # lemmatizer.lemmatize('houses','n')
    print(tagged_word)
# Out:
# house
# run
# dog
# well
# cat
# fly
# geese
# study
# wolves
# child
# foot
