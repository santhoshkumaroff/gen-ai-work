# %%
import nltk

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrator\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

stop_words  = stopwords.words('english')

# %%
with open(r"C:\Users\Administrator\OneDrive\Desktop\Gen_AI_\Text_normalization\data.txt") as file:
    data = file.read()

# %%
data
# Out:
# "open     file and return a stream.  raise oserror upon failure.\nfile is either a text or  byte string giving the name \n(and the path if the file isn't in the current working directory) \nof the file to be opened    or an integer \nfile descriptor of the     file to be wrapped. \n(if a file descriptor is given, it is closed when the returned i/o object\n is closed, unless closefd is set to false.)"

# %% [markdown]
# Word-level + stopwords

# %%
from nltk.tokenize import word_tokenize
tokens = word_tokenize(data)

# %%
updated_tokens = []
for word in tokens:
    if word not in stop_words:
        updated_tokens.append(word)
print(updated_tokens)
# Out:
# ['open', 'file', 'return', 'stream', '.', 'raise', 'oserror', 'upon', 'failure', '.', 'file', 'either', 'text', 'byte', 'string', 'giving', 'name', '(', 'path', 'file', "n't", 'current', 'working', 'directory', ')', 'file', 'opened', 'integer', 'file', 'descriptor', 'file', 'wrapped', '.', '(', 'file', 'descriptor', 'given', ',', 'closed', 'returned', 'i/o', 'object', 'closed', ',', 'unless', 'closefd', 'set', 'false', '.', ')']

# %%
print(stop_words)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %% [markdown]
# data + stop_words

# %%
stop_words = ['a','in']
data = 'absoulte inplace a in'
for word in stop_words: #'a'
    if word in data:
        data = data.replace(word,'')
print(data)
# Out:
# bsoulte plce

# %% [markdown]
# sentence-level + stop_words

# %%
nlp_sentences = [
    "The quick brown fox jumps over the lazy dog.",
    "Open the file and return a stream; raise OSError on failure.",
    "Can you schedule the meeting for 3pm tomorrow?",
    "I can't access the server at https://example.com/api/v1/status.",
    "She bought 12 apples, 3 oranges, and a bunch of bananas.",
    "Natural language processing is transforming many industries.",
    "Isn't it fascinating how models learn from large datasets?",
    "The temperature dropped to -5°C last night in New York.",
    "Please refactor the function: def compute(x): return x*x.",
    "Wow! That movie exceeded all expectations :)"
]

# %%
from nltk.tokenize import sent_tokenize

sent_tokens = sent_tokenize(data)

updated_tokens = []
for word in sent_tokens:
    if word not in stop_words:
        updated_tokens.append(word)
print(updated_tokens)
# Out:
# ['bsoulte plce']

# %%
import nltk

from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

lemmatizer = WordNetLemmatizer()

# Convert NLTK POS tag to WordNet POS
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # Default

text = "The children are running and ate apples happily."

tokens = word_tokenize(text)

pos_tags = nltk.pos_tag(tokens)

lemmatized_words = []

for word, tag in pos_tags:
    wn_tag = get_wordnet_pos(tag)
    lemma = lemmatizer.lemmatize(word, pos=wn_tag)
    lemmatized_words.append(lemma)

print(lemmatized_words)
# Out:
# ['The', 'child', 'be', 'run', 'and', 'ate', 'apple', 'happily', '.']

# %%
wordnet.tag2pos()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 wordnet.tag2pos()
#
# TypeError: WordNetCorpusReader.tag2pos() missing 1 required positional argument: 'tag'
