# %%
pip install contractions
# Out:
# Collecting contractions
#   Downloading contractions-0.1.73-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting textsearch>=0.0.21 (from contractions)
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting anyascii (from textsearch>=0.0.21->contractions)
#   Using cached anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting pyahocorasick (from textsearch>=0.0.21->contractions)
#   Downloading pyahocorasick-2.3.1-cp313-cp313-win_amd64.whl.metadata (14 kB)
# Downloading contractions-0.1.73-py2.py3-none-any.whl (8.7 kB)
# Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Using cached anyascii-0.3.3-py3-none-any.whl (345 kB)
# Downloading pyahocorasick-2.3.1-cp313-cp313-win_amd64.whl (35 kB)
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
#
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    ---------- ----------------------------- 1/4 [anyascii]
#    -------------------- ------------------- 2/4 [textsearch]
#    ------------------------------ --------- 3/4 [contractions]
#    ---------------------------------------- 4/4 [contractions]
#
# Successfully installed anyascii-0.3.3 contractions-0.1.73 pyahocorasick-2.3.1 textsearch-0.0.24
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import contractions

text = "I'm happy u because I can't attend. ASAP btw"

expanded = contractions.fix(text)

print(expanded)
# Out:
# I am happy you because I cannot attend. AS SOON AS POSSIBLE by the way IAS

# %%
pip install emoji
# Out:
# Collecting emoji
#   Using cached emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Using cached emoji-2.15.0-py3-none-any.whl (608 kB)
# Installing collected packages: emoji
# Successfully installed emoji-2.15.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import emoji
text = "I love NLP 😊❤️"
print(emoji.replace_emoji(text, replace=""))
# Out:
# I love NLP

# %%
import emoji


text = "I love NLP 😊❤️❤️💔"

print(emoji.demojize(text))
# Out:
# I love NLP :smiling_face_with_smiling_eyes::red_heart::red_heart::broken_heart:

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: nltk>=3.9 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from textblob) (3.9.4)
# Requirement already satisfied: click in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (8.3.0)
# Requirement already satisfied: joblib in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9->textblob) (4.67.1)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\local\programs\python\python313\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 8.2 MB/s eta 0:00:00
# Installing collected packages: textblob
# Successfully installed textblob-0.20.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from textblob import TextBlob

text = "I hav a gooo daiy"

corrected = TextBlob(text).correct()

print(corrected)
# Out:
# I had a good day
