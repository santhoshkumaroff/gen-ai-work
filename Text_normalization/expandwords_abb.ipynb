# %%
# pip install contractions

# %%
import contractions

# %%
s1="I'm not Okay"
s2 = "btw ASAP I'll try to complete the task"
contractions.fix(s1)
# Out:
# 'I am not Okay'

# %%
contractions.fix(s2)
# Out:
# 'AS SOON AS POSSIBLE I will try to complete the task'
