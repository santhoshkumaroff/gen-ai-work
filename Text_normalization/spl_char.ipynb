# %%
with open('data.txt','r') as file:
    data = file.read()
    for char in data:
        if not char.isalnum() and not ord(char)==32:
            data = data.replace(char,'')
            # print(data)
            # print()
print(data)
# Out:
# open file and return a stream raise oserror upon failurefile is either a text or byte string giving the name and the path if the file isnt in the current working directory of the file to be opened or an integer file descriptor of the file to be wrapped if a file descriptor is given it is closed when the returned io object is closed unless closefd is set to false

# %%
ord(' ')
# Out:
# 32
