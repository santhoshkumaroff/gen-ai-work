# %%
pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.6.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (4.53.3)
# Requirement already satisfied: huggingface-hub>=0.23.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: torch>=1.11.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy>=1.20.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (2.3.5)
# Requirement already satisfied: scikit-learn>=0.22.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (1.8.0)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sentence-transformers) (4.65.2)
# Requirement already satisfied: filelock in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.1.15)
# Requirement already satisfied: requests in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2.34.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2024.12.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from torch>=1.11.0->sentence-transformers) (82.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from tqdm>=4.0.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from requests->transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.1.4)
# Downloading sentence_transformers-5.6.1-py3-none-any.whl (596 kB)
#    ---------------------------------------- 0.0/596.7 kB ? eta -:--:--
#    ----------------------------------- ---- 524.3/596.7 kB 8.0 MB/s eta 0:00:01
#    ----------------------------------- ---- 524.3/596.7 kB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 596.7/596.7 kB 774.3 kB/s  0:00:00
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.6.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sentence_transformers import SentenceTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
data = open('data.txt').read()
data
# Out:
# "open     file and return a stream.  raise oserror upon failure.\nfile is either a text or  byte string giving the name \n(and the path if the file isn't in the current working directory) \nof the file to be opened    or an integer \nfile descriptor of the     file to be wrapped. \n(if a file descriptor is given, it is closed when the returned i/o object\n is closed, unless closefd is set to false.)"

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 20
)

# %%
chunks = splitter.split_text(data) #list of strings(chunks)
print(chunks,type(chunks),type(chunks[0]))
# Out:
# ['open     file and return a stream.  raise oserror upon failure.', 'file is either a text or  byte string giving the name', "(and the path if the file isn't in the current working directory)", 'of the file to be opened    or an integer \nfile descriptor of the     file to be wrapped.', '(if a file descriptor is given, it is closed when the returned i/o object', 'is closed, unless closefd is set to false.)'] <class 'list'> <class 'str'>

# %%
embeddings = SentenceTransformer(
    model_name_or_path = 'sentence-transformers/all-miniLM-L6-V2'    
)

# %%
embeddings.encode(chunks)
# Out:
# array([[-6.1592780e-02,  2.6425404e-02, -2.7104862e-02, ...,
#          4.6571057e-02,  6.1230898e-02,  6.1719362e-02],
#        [-4.8916643e-03,  4.8853293e-02, -8.4833570e-02, ...,
#          3.3059004e-03,  4.7197763e-02, -4.8311842e-03],
#        [-2.6636072e-02,  4.6755090e-02, -6.0191877e-02, ...,
#          5.6604661e-02,  8.9681573e-02,  2.6625907e-02],
#        [-3.3293776e-02,  7.6282486e-02, -1.2072307e-01, ...,
#          6.6578002e-03,  7.0393130e-02,  6.2281717e-02],
#        [-5.1085342e-02,  4.7625400e-02, -4.2513523e-02, ...,
#          4.0153876e-02, -2.1186113e-02, -3.8445238e-02],
#        [ 3.4820229e-02, -2.7095383e-02, -7.1363822e-02, ...,
#          1.7073948e-02,  2.5866939e-05, -8.0028158e-03]],
#       shape=(6, 384), dtype=float32)
