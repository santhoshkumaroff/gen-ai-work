# %%
# pip show langchain

# %%
pip install langchain_google_genai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-4.3.2-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain_google_genai) (1.2.0)
# Collecting google-genai<3.0.0,>=1.65.0 (from langchain_google_genai)
#   Downloading google_genai-2.16.0-py3-none-any.whl.metadata (56 kB)
# Collecting langchain-core<2.0.0,>=1.5.1 (from langchain_google_genai)
#   Downloading langchain_core-1.5.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain_google_genai) (2.12.5)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.65.0->langchain_google_genai) (4.14.0)
# Collecting google-auth<3.0.0,>=2.56.0 (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain_google_genai)
#   Downloading google_auth-2.56.2-py3-none-any.whl.metadata (6.0 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.65.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.65.0->langchain_google_genai) (2.34.2)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.65.0->langchain_google_genai) (9.1.2)
# Collecting websockets<17.0,>=13.0.0 (from google-genai<3.0.0,>=1.65.0->langchain_google_genai)
#   Downloading websockets-16.1.1-cp314-cp314-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.65.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.65.0->langchain_google_genai) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-genai<3.0.0,>=1.65.0->langchain_google_genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: cryptography>=41.0.5 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (49.0.0)
# Requirement already satisfied: certifi in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.5.1->langchain_google_genai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (2.6.3)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from cffi>=2.0.0->cryptography>=41.0.5->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=1.65.0->langchain_google_genai) (0.6.2)
# Downloading langchain_google_genai-4.3.2-py3-none-any.whl (72 kB)
# Downloading google_genai-2.16.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 5.6 MB/s  0:00:00
# Downloading google_auth-2.56.2-py3-none-any.whl (258 kB)
# Downloading langchain_core-1.5.3-py3-none-any.whl (561 kB)
#    ---------------------------------------- 0.0/561.7 kB ? eta -:--:--
#    ---------------------------------------- 561.7/561.7 kB 6.6 MB/s  0:00:00
# Downloading websockets-16.1.1-cp314-cp314-win_amd64.whl (179 kB)
# Installing collected packages: websockets, google-auth, langchain-core, google-genai, langchain_google_genai
#
#   Attempting uninstall: websockets
#
#     Found existing installation: websockets 12.0
#
#     Uninstalling websockets-12.0:
#
#       Successfully uninstalled websockets-12.0
#
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#    ---------------------------------------- 0/5 [websockets]
#   Attempting uninstall: google-auth
#    ---------------------------------------- 0/5 [websockets]
#     Found existing installation: google-auth 2.55.1
#    ---------------------------------------- 0/5 [websockets]
#    -------- ------------------------------- 1/5 [google-auth]
#     Uninstalling google-auth-2.55.1:
#    -------- ------------------------------- 1/5 [google-auth]
#       Successfully uninstalled google-auth-2.55.1
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#    -------- ------------------------------- 1/5 [google-auth]
#   Attempting uninstall: langchain-core
#    -------- ------------------------------- 1/5 [google-auth]
#     Found existing installation: langchain-core 1.4.7
#    -------- ------------------------------- 1/5 [google-auth]
#    ---------------- ----------------------- 2/5 [langchain-core]
#     Uninstalling langchain-core-1.4.7:
#    ---------------- ----------------------- 2/5 [langchain-core]
#       Successfully uninstalled langchain-core-1.4.7
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ---------------- ----------------------- 2/5 [langchain-core]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    ------------------------ --------------- 3/5 [google-genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    -------------------------------- ------- 4/5 [langchain_google_genai]
#    ---------------------------------------- 5/5 [langchain_google_genai]
#
# Successfully installed google-auth-2.56.2 google-genai-2.16.0 langchain-core-1.5.3 langchain_google_genai-4.3.2 websockets-16.1.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip show langchain_google_genai
# Out:
# Name: langchain-google-genai
# Version: 4.3.2
# Summary: An integration package connecting Google's genai package and LangChain
# Home-page: https://docs.langchain.com/oss/python/integrations/providers/google
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\Administrator\AppData\Roaming\Python\Python314\site-packages
# Requires: filetype, google-genai, langchain-core, pydantic
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
llm_model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash", #gemini-3.5-flash,gemini-3.6-flash,gemini-2.5-pro
    api_key=os.environ['GEMINI_API_KEY']
)

# %%
response = llm_model.invoke("Explain GenAI ?")
response
# Out:
# AIMessage(content='**Generative AI (GenAI)** is a type of artificial intelligence that focuses on creating new, original content rather than just analyzing or classifying existing data.\n\nThink of it this way:\n*   **Traditional AI** might tell you if a picture contains a cat, or predict the stock market.\n*   **Generative AI** can *draw* a new cat that\'s never existed before, or *write* a poem about the stock market.\n\n### How it Works (Simplified):\n\n1.  **Learns from Massive Data:** GenAI models are trained on enormous datasets of existing content – text, images, audio, video, code, etc. During this training, they learn patterns, structures, styles, and relationships within the data. They don\'t "understand" in a human sense, but they become incredibly good at predicting what comes next in a sequence or what elements typically go together.\n2.  **Receives a Prompt:** A user provides an instruction, often called a "prompt," describing what they want the AI to generate (e.g., "Write a short story about a space explorer finding a new planet," or "Generate an image of a red panda wearing a top hat").\n3.  **Generates New Content:** Based on the prompt and its learned patterns, the GenAI model creates entirely new content that aligns with the instruction and has characteristics similar to its training data. It\'s not copying; it\'s synthesizing new information.\n\n### Key Characteristics & Capabilities:\n\n*   **Creation of Novel Content:** Its primary function is to produce something new and unique.\n*   **Multimodality:** Can generate various types of content:\n    *   **Text:** Articles, stories, poems, code, summaries, emails, chatbots (e.g., ChatGPT, Bard).\n    *   **Images:** Art, photos, designs, mockups (e.g., DALL-E, Midjourney, Stable Diffusion).\n    *   **Audio:** Music, voiceovers, sound effects.\n    *   **Video:** Short clips, animations, deepfakes (though this raises ethical concerns).\n    *   **Code:** Program snippets, functions, debugging assistance.\n*   **Contextual Understanding (Apparent):** Can follow complex instructions and generate outputs that make sense within a given context.\n*   **Learning & Adaptation:** Continuously improves as it\'s exposed to more data and refined through further training.\n\n### Why is it a Big Deal?\n\n*   **Democratization of Creativity:** Lowers the barrier for creating high-quality content across various mediums.\n*   **Productivity Boost:** Automates tedious and time-consuming tasks like drafting emails, summarizing documents, or generating initial design concepts.\n*   **Innovation:** Opens up new possibilities for product development, entertainment, education, and scientific research.\n*   **Natural Interaction:** Enables more intuitive and conversational ways for humans to interact with computers.\n\n### Important Considerations & Limitations:\n\n*   **Hallucinations:** GenAI can sometimes generate plausible-sounding but factually incorrect or nonsensical information.\n*   **Bias:** It can inherit and amplify biases present in its training data, leading to unfair or stereotypical outputs.\n*   **Ethical Concerns:** Issues around copyright, misinformation, deepfakes, job displacement, and the responsible use of powerful AI.\n*   **Lack of True Understanding/Consciousness:** While impressive, GenAI doesn\'t "think" or "understand" in the human sense. It\'s a sophisticated pattern-matching and generation engine.\n*   **Computational Cost:** Training and running these models can be very resource-intensive and expensive.\n\nIn essence, Generative AI represents a significant leap forward in AI capabilities, shifting from analysis to creation, and fundamentally changing how we interact with and leverage artificial intelligence.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fbd85-d89d-79a1-b363-451502783ce5-0', tool_calls=[], invalid_tool_calls ...

# %%
response.content
# Out:
# '**Generative AI (GenAI)** is a type of artificial intelligence that focuses on creating new, original content rather than just analyzing or classifying existing data.\n\nThink of it this way:\n*   **Traditional AI** might tell you if a picture contains a cat, or predict the stock market.\n*   **Generative AI** can *draw* a new cat that\'s never existed before, or *write* a poem about the stock market.\n\n### How it Works (Simplified):\n\n1.  **Learns from Massive Data:** GenAI models are trained on enormous datasets of existing content – text, images, audio, video, code, etc. During this training, they learn patterns, structures, styles, and relationships within the data. They don\'t "understand" in a human sense, but they become incredibly good at predicting what comes next in a sequence or what elements typically go together.\n2.  **Receives a Prompt:** A user provides an instruction, often called a "prompt," describing what they want the AI to generate (e.g., "Write a short story about a space explorer finding a new planet," or "Generate an image of a red panda wearing a top hat").\n3.  **Generates New Content:** Based on the prompt and its learned patterns, the GenAI model creates entirely new content that aligns with the instruction and has characteristics similar to its training data. It\'s not copying; it\'s synthesizing new information.\n\n### Key Characteristics & Capabilities:\n\n*   **Creation of Novel Content:** Its primary function is to produce something new and unique.\n*   **Multimodality:** Can generate various types of content:\n    *   **Text:** Articles, stories, poems, code, summaries, emails, chatbots (e.g., ChatGPT, Bard).\n    *   **Images:** Art, photos, designs, mockups (e.g., DALL-E, Midjourney, Stable Diffusion).\n    *   **Audio:** Music, voiceovers, sound effects.\n    *   **Video:** Short clips, animations, deepfakes (though this raises ethical concerns).\n    *   **Code:** Program snippets, functions, debugging assistance.\n*   **Contextual Understanding (Apparent):** Can follow complex instructions and generate outputs that make sense within a given context.\n*   **Learning & Adaptation:** Continuously improves as it\'s exposed to more data and refined through further training.\n\n### Why is it a Big Deal?\n\n*   **Democratization of Creativity:** Lowers the barrier for creating high-quality content across various mediums.\n*   **Productivity Boost:** Automates tedious and time-consuming tasks like drafting emails, summarizing documents, or generating initial design concepts.\n*   **Innovation:** Opens up new possibilities for product development, entertainment, education, and scientific research.\n*   **Natural Interaction:** Enables more intuitive and conversational ways for humans to interact with computers.\n\n### Important Considerations & Limitations:\n\n*   **Hallucinations:** GenAI can sometimes generate plausible-sounding but factually incorrect or nonsensical information.\n*   **Bias:** It can inherit and amplify biases present in its training data, leading to unfair or stereotypical outputs.\n*   **Ethical Concerns:** Issues around copyright, misinformation, deepfakes, job displacement, and the responsible use of powerful AI.\n*   **Lack of True Understanding/Consciousness:** While impressive, GenAI doesn\'t "think" or "understand" in the human sense. It\'s a sophisticated pattern-matching and generation engine.\n*   **Computational Cost:** Training and running these models can be very resource-intensive and expensive.\n\nIn essence, Generative AI represents a significant leap forward in AI capabilities, shifting from analysis to creation, and fundamentally changing how we interact with and leverage artificial intelligence.'
